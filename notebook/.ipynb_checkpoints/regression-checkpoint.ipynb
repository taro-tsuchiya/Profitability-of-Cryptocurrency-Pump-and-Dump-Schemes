# %% [markdown]
# # Regression

# %%
# %matplotlib inline
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('pnd_data.csv')

# %%
data['theoretical return'] = data['theoretical profit(%)'] +1

# %%
data.head()
# Out:
#                   date  order             channel  subscriber_0901 currency  \
# 0  2018-06-17 18:15:29    535          CryptoPump              0.0      KRL
# 1  2018-06-17 19:45:02    534     Tornado Signals            927.0     BNBX
# 2  2018-06-18 17:59:05    533  Shark Pump Signals            833.0    NETKO
# 3  2018-06-18 19:45:03    532     Tornado Signals            927.0       RR
# 4  2018-06-19 19:45:02    531     Tornado Signals            927.0      WIT
#
#    exchange  duration  volume  price before pump     max price  ...  ranked  \
# 0         1         1    0.04       8.990000e-06  1.050000e-05  ...       1
# 1         1        91    0.12       1.027000e-05  2.300000e-05  ...       0
# 2         1       319    0.05       1.152000e-05  1.482000e-05  ...       0
# 3         1         9    0.16       4.600000e-07  1.800000e-06  ...       0
# 4         1         5    0.16       1.000000e-07  4.500000e-07  ...       1
#
#     coin cap  coin volume  coin ranking month  weekday hour  hour_cos  \
# 0  1371405.0        772.0           655     6        6   18  0.203456
# 1        0.0          0.0             0     6        6   19  0.460065
# 2        0.0          0.0             0     6        0   17 -0.068242
# 3        0.0          0.0             0     6        0   19  0.460065
# 4    31477.0      22253.0          1068     6        1   19  0.460065
#
#    hour_sin  theoretical return
# 0 -0.979084              1.0000
# 1 -0.887885              1.2112
# 2 -0.997669              1.2865
# 3 -0.887885              1.2950
# 4 -0.887885              2.0455
#
# [5 rows x 27 columns]

# %%
data.describe()
# Out:
#             order  subscriber_0901    exchange     duration       volume  \
# count  535.000000       535.000000  535.000000   535.000000   535.000000
# mean   268.000000     15906.416822    0.446729   164.502804    70.590654
# std    154.585467     26671.153718    0.497619   276.475083   351.399044
# min      1.000000         0.000000    0.000000     0.000000     0.000000
# 25%    134.500000       433.500000    0.000000    16.000000     0.170000
# 50%    268.000000      2210.000000    0.000000    58.000000     2.600000
# 75%    401.500000     13612.000000    1.000000   185.000000    39.650000
# max    535.000000    248813.000000    1.000000  2368.000000  6683.360000
#
#        price before pump     max price  our buy price  our profit(%)  \
# count       5.350000e+02  5.350000e+02     535.000000     535.000000
# mean        3.829451e-04  4.314070e-04       0.000242       0.181480
# std         3.836848e-03  3.865655e-03       0.003475       0.646062
# min         1.000000e-07  1.400000e-07       0.000000      -0.641000
# 25%         2.965000e-06  4.575000e-06       0.000000       0.000000
# 50%         1.191000e-05  1.570000e-05       0.000002       0.000000
# 75%         5.929500e-05  7.245000e-05       0.000017       0.075300
# max         7.956478e-02  7.948000e-02       0.079241       8.142900
#
#        theoretical buy price  ...      ranked      coin cap   coin volume  \
# count           5.350000e+02  ...  535.000000  5.350000e+02  5.350000e+02
# mean            4.020585e-04  ...    0.829907  6.875394e+07  4.350316e+07
# std             3.849477e-03  ...    0.376067  3.882025e+08  6.022037e+08
# min             1.500000e-07  ...    0.000000  0.000000e+00  0.000000e+00
# 25%             3.335000e-06  ...    1.000000  3.128789e+06  3.040900e+04
# 50%             1.336000e-05  ...    1.000000  7.836234e+06  2.109780e+05
# 75%             6.154500e-05  ...    1.000000  2.464420e+07  1.873066e+06
# max             7.948000e-02  ...    1.000000  5.064739e+09  1.366279e+10
#
#        coin ranking       month     weekday        hour    hour_cos  \
# count    535.000000  535.000000  535.000000  535.000000  535.000000
# mean     224.777570    5.908411    3.085981   14.005607    0.035693
# std      219.570941    2.959310    2.014946    5.901974    0.527752
# min        0.000000    1.000000    0.000000    0.000000   -0.990686
# 25%       58.000000    3.000000    1.000000   12.000000   -0.334880
# 50%      165.000000    6.000000    3.000000   17.000000   -0.068242
# 75%      330.500000    8.000000    5.000000   18.000000    0.460065
# max     1249.000000   12.000000    6.000000   23.000000    1.000000
#
#          hour_sin  theoretical return
# count  535.000000          535.000000
# mean    -0.543712            1.400478
# std      0.652609            0.861851
# min     -0.997669            0.359000
# 25%     -0.997669            1.002950
# 50%     -0.887885            1.056500
# 75%     -0.136167            1.398100
# max      0.997669            9.589000
#
# [8 rows x 22 columns]

# %% [markdown]
# ## check the normality

# %%
#theoretical profit
profit = data['theoretical profit(%)'].values
plt.hist(profit, bins = 100)
plt.xlabel('theoretical profit')
plt.grid(True)
print(data['theoretical profit(%)'].skew())
# Out:
# 4.5285232207899675

# %%
#theoretical return
plt.hist(data['theoretical return'], bins = 100)
plt.xlabel('theoretical return')
plt.grid(True)
print(data['theoretical return'].skew())
# Out:
# 4.5285232207899675

# %%
log_after_value = np.log(data['theoretical return'])
print(log_after_value.skew())
plt.hist(log_after_value, bins = 100)
plt.xlabel('theoretical return (log)')
plt.grid(True)
# Out:
# 1.7981790780293023

# %% [markdown]
# ## GLM

# %% [markdown]
# ### model1

# %%
#dependent and indepenedet variables
y = data['theoretical return']
x = data[['month','weekday', 'hour','subscriber_0901','exchange', 'duration', 'volume',
        'ranked']]

# %%
#ols model
import statsmodels.api as sm
from scipy import stats
x_t = sm.add_constant(x)
est = sm.OLS(y,x_t)
est2 = est.fit()
print(est2.aic)
est2.summary()
# Out:
# 1258.3626546137864
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     theoretical return   R-squared:                       0.198
# Model:                            OLS   Adj. R-squared:                  0.185
# Method:                 Least Squares   F-statistic:                     16.20
# Date:                Mon, 23 Mar 2020   Prob (F-statistic):           1.76e-21
# Time:                        20:47:58   Log-Likelihood:                -620.18
# No. Observations:                 535   AIC:                             1258.
# Df Residuals:                     526   BIC:                             1297.
# Df Model:                           8
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               1.2732      0.171      7.448      0.000       0.937       1.609
# month              -0.0214      0.012     -1.799      0.073      -0.045       0.002
# weekday            -0.0154      0.017     -0.908      0.364      -0.049       0.018
# hour               -0.0111      0.006     -1.848      0.065      -0.023       0.001
# subscriber_0901 -1.892e-06   1.42e-06     -1.333      0.183   -4.68e-06    8.97e-07
# exchange            0.7480      0.079      9.502      0.000       0.593       0.903
# duration        -3.993e-05      0.000     -0.314      0.754      -0.000       0.000
# volume          -1.253e-05      0.000     -0.125      0.900      -0.000       0.000
# ranked              0.1939      0.095      2.038      0.042       0.007       0.381
# ==============================================================================
# Omnibus:                      543.562   Durbin-Watson:                   2.159
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            28994.065
# Skew:                           4.487   Prob(JB):                         0.00
# Kurtosis:                      37.931   Cond. No.                     1.70e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.7e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#ols model (glm) * just to check
est = sm.GLM(y,x_t,family=sm.families.Gaussian())
est2 = est.fit()
print(est2.aic)
est2.summary()
# Out:
# 1258.3626546137864
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     theoretical return   No. Observations:                  535
# Model:                            GLM   Df Residuals:                      526
# Model Family:                Gaussian   Df Model:                            8
# Link Function:               identity   Scale:                         0.60503
# Method:                          IRLS   Log-Likelihood:                -620.18
# Date:                Mon, 23 Mar 2020   Deviance:                       318.25
# Time:                        20:47:58   Pearson chi2:                     318.
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               1.2732      0.171      7.448      0.000       0.938       1.608
# month              -0.0214      0.012     -1.799      0.072      -0.045       0.002
# weekday            -0.0154      0.017     -0.908      0.364      -0.049       0.018
# hour               -0.0111      0.006     -1.848      0.065      -0.023       0.001
# subscriber_0901 -1.892e-06   1.42e-06     -1.333      0.183   -4.67e-06     8.9e-07
# exchange            0.7480      0.079      9.502      0.000       0.594       0.902
# duration        -3.993e-05      0.000     -0.314      0.753      -0.000       0.000
# volume          -1.253e-05      0.000     -0.125      0.900      -0.000       0.000
# ranked              0.1939      0.095      2.038      0.042       0.007       0.380
# ===================================================================================
# """

# %%
#ols model + log 
import statsmodels.api as sm
from scipy import stats
x_t = sm.add_constant(x)
est = sm.GLM(y,x_t,family=sm.families.Gaussian(link=sm.families.links.log))
est2 = est.fit()
print(est2.aic)
est2.summary()
# Out:
# 1249.5999096436149
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     theoretical return   No. Observations:                  535
# Model:                            GLM   Df Residuals:                      526
# Model Family:                Gaussian   Df Model:                            8
# Link Function:                    log   Scale:                         0.59512
# Method:                          IRLS   Log-Likelihood:                -615.80
# Date:                Mon, 23 Mar 2020   Deviance:                       313.03
# Time:                        20:47:58   Pearson chi2:                     313.
# No. Iterations:                     9
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.3172      0.130      2.443      0.015       0.063       0.572
# month              -0.0216      0.009     -2.411      0.016      -0.039      -0.004
# weekday            -0.0114      0.011     -0.996      0.319      -0.034       0.011
# hour               -0.0124      0.004     -2.982      0.003      -0.021      -0.004
# subscriber_0901 -2.063e-06   1.35e-06     -1.527      0.127   -4.71e-06    5.84e-07
# exchange            0.5427      0.059      9.182      0.000       0.427       0.659
# duration        -3.038e-05      0.000     -0.283      0.777      -0.000       0.000
# volume          -6.138e-06   9.02e-05     -0.068      0.946      -0.000       0.000
# ranked              0.1295      0.065      1.998      0.046       0.002       0.257
# ===================================================================================
# """

# %%
#gamma model, inverse
x_t = sm.add_constant(x)
est = sm.GLM(y,x_t,family=sm.families.Gamma())
est2 = est.fit()
print(est2.aic)
est2.summary()
# Out:
# 719.5047714038905
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     theoretical return   No. Observations:                  535
# Model:                            GLM   Df Residuals:                      526
# Model Family:                   Gamma   Df Model:                            8
# Link Function:          inverse_power   Scale:                         0.17960
# Method:                          IRLS   Log-Likelihood:                -350.75
# Date:                Mon, 23 Mar 2020   Deviance:                       65.681
# Time:                        20:47:58   Pearson chi2:                     94.5
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.7890      0.071     11.093      0.000       0.650       0.928
# month               0.0118      0.005      2.440      0.015       0.002       0.021
# weekday             0.0063      0.006      1.005      0.315      -0.006       0.019
# hour                0.0059      0.002      2.581      0.010       0.001       0.010
# subscriber_0901  1.265e-06   7.15e-07      1.768      0.077   -1.37e-07    2.67e-06
# exchange           -0.3692      0.032    -11.430      0.000      -0.432      -0.306
# duration         3.348e-05   5.86e-05      0.571      0.568   -8.14e-05       0.000
# volume            1.76e-06   4.96e-05      0.036      0.972   -9.54e-05    9.89e-05
# ranked             -0.0665      0.035     -1.889      0.059      -0.135       0.002
# ===================================================================================
# """

# %%
#gamma model, log
import statsmodels.api as sm
from scipy import stats
x_t = sm.add_constant(x)
est = sm.GLM(y,x_t,family=sm.families.Gamma(link=sm.families.links.log))
est2 = est.fit()
print(est2.aic)
est2.summary()
# Out:
# 735.4181414602049
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     theoretical return   No. Observations:                  535
# Model:                            GLM   Df Residuals:                      526
# Model Family:                   Gamma   Df Model:                            8
# Link Function:                    log   Scale:                         0.18715
# Method:                          IRLS   Log-Likelihood:                -358.71
# Date:                Mon, 23 Mar 2020   Deviance:                       67.171
# Time:                        20:47:58   Pearson chi2:                     98.4
# No. Iterations:                    13
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.1978      0.095      2.080      0.038       0.011       0.384
# month              -0.0120      0.007     -1.816      0.069      -0.025       0.001
# weekday            -0.0094      0.009     -0.995      0.320      -0.028       0.009
# hour               -0.0052      0.003     -1.567      0.117      -0.012       0.001
# subscriber_0901 -1.287e-06    7.9e-07     -1.630      0.103   -2.83e-06     2.6e-07
# exchange            0.5058      0.044     11.552      0.000       0.420       0.592
# duration        -4.534e-05   7.07e-05     -0.641      0.521      -0.000    9.32e-05
# volume          -3.591e-06   5.57e-05     -0.065      0.949      -0.000       0.000
# ranked              0.0957      0.053      1.807      0.071      -0.008       0.199
# ===================================================================================
# """

# %% [markdown]
# ## control conditions

# %%
#calculate vif
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["vif"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif["features"] = x.columns
print(vif)

plt.plot(vif["vif"])
# Out:
#         vif         features
# 0  3.864441            month
# 1  3.229107          weekday
# 2  4.957425             hour
# 3  1.658308  subscriber_0901
# 4  2.233601         exchange
# 5  1.470962         duration
# 6  1.114465           volume
# 7  4.325890           ranked

# %% [markdown]
# ### divide samples into Yobit and Binance (exchanges)

# %%
yobit = data[data['exchange2']=='Yobit']
binance = data[data['exchange2']=='Binance']
bittrex = data[data['exchange2']=='Bittrex']

# %%
three = [yobit, binance, bittrex]
for i in three:
    print(i.shape)
# Out:
# (239, 27)
# (261, 27)
# (35, 27)

# %%
for i in three:
    print('the average profit is {}'.format(i['theoretical profit(%)'].mean()))
# Out:
# the average profit is 0.8025912133891209
# the average profit is 0.06037739463601532
# the average profit is 0.19079714285714286

# %%
plt.hist(yobit['theoretical return'], bins = 100)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.hist(binance['theoretical return'], bins = 100)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### model2

# %%
#dependent and indepenedet variables in Yobit
y = yobit['theoretical return']
x = yobit[['month','weekday', 'hour','subscriber_0901','duration', 'volume',
        'ranked']]

# %%
#ols model
import statsmodels.api as sm
from scipy import stats
x_t = sm.add_constant(x)
est = sm.OLS(y,x_t)
est2 = est.fit()
print(est2.aic)
est2.summary()
# Out:
# 709.6565300674354
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     theoretical return   R-squared:                       0.199
# Model:                            OLS   Adj. R-squared:                  0.175
# Method:                 Least Squares   F-statistic:                     8.189
# Date:                Mon, 23 Mar 2020   Prob (F-statistic):           6.56e-09
# Time:                        20:47:59   Log-Likelihood:                -346.83
# No. Observations:                 239   AIC:                             709.7
# Df Residuals:                     231   BIC:                             737.5
# Df Model:                           7
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               2.6879      0.403      6.673      0.000       1.894       3.482
# month              -0.0519      0.027     -1.892      0.060      -0.106       0.002
# weekday            -0.0293      0.035     -0.848      0.398      -0.097       0.039
# hour               -0.0555      0.015     -3.647      0.000      -0.085      -0.025
# subscriber_0901 -2.225e-06    6.8e-06     -0.327      0.744   -1.56e-05    1.12e-05
# duration           -0.0002      0.000     -0.588      0.557      -0.001       0.001
# volume              1.8248      0.292      6.242      0.000       1.249       2.401
# ranked              0.0009      0.171      0.005      0.996      -0.335       0.337
# ==============================================================================
# Omnibus:                      134.680   Durbin-Watson:                   2.103
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1038.042
# Skew:                           2.117   Prob(JB):                    3.91e-226
# Kurtosis:                      12.291   Cond. No.                     6.89e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.89e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#ols model + log 
import statsmodels.api as sm
from scipy import stats
x_t = sm.add_constant(x)
est = sm.GLM(y,x_t,family=sm.families.Gaussian(link=sm.families.links.log))
est2 = est.fit()
print(est2.aic)
est2.summary()
# Out:
# 700.6152563881456
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     theoretical return   No. Observations:                  239
# Model:                            GLM   Df Residuals:                      231
# Model Family:                Gaussian   Df Model:                            7
# Link Function:                    log   Scale:                          1.0619
# Method:                          IRLS   Log-Likelihood:                -342.31
# Date:                Mon, 23 Mar 2020   Deviance:                       245.31
# Time:                        20:47:59   Pearson chi2:                     245.
# No. Iterations:                    10
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               1.1194      0.215      5.214      0.000       0.699       1.540
# month              -0.0271      0.016     -1.680      0.093      -0.059       0.005
# weekday            -0.0385      0.017     -2.217      0.027      -0.073      -0.004
# hour               -0.0301      0.007     -4.114      0.000      -0.044      -0.016
# subscriber_0901  -1.24e-06   4.21e-06     -0.295      0.768   -9.48e-06       7e-06
# duration        -8.041e-05      0.000     -0.320      0.749      -0.001       0.000
# volume              0.8567      0.094      9.077      0.000       0.672       1.042
# ranked              0.0008      0.102      0.008      0.994      -0.199       0.201
# ===================================================================================
# """

# %%
#gamma model, inverse
x_t = sm.add_constant(x)
est = sm.GLM(y,x_t,family=sm.families.Gamma())
est2 = est.fit()
print(est2.aic)
est2.summary()
# Out:
# 555.8957403794122
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     theoretical return   No. Observations:                  239
# Model:                            GLM   Df Residuals:                      231
# Model Family:                   Gamma   Df Model:                            7
# Link Function:          inverse_power   Scale:                         0.27182
# Method:                          IRLS   Log-Likelihood:                -269.95
# Date:                Mon, 23 Mar 2020   Deviance:                       50.044
# Time:                        20:47:59   Pearson chi2:                     62.8
# No. Iterations:                    12
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.3290      0.110      3.000      0.003       0.114       0.544
# month               0.0147      0.008      1.788      0.074      -0.001       0.031
# weekday             0.0065      0.009      0.736      0.461      -0.011       0.024
# hour                0.0144      0.004      3.913      0.000       0.007       0.022
# subscriber_0901   5.84e-07    2.1e-06      0.278      0.781   -3.54e-06     4.7e-06
# duration         4.346e-05      0.000      0.349      0.727      -0.000       0.000
# volume             -0.2947      0.043     -6.889      0.000      -0.379      -0.211
# ranked             -0.0222      0.052     -0.427      0.669      -0.124       0.080
# ===================================================================================
# """

# %%
#gamma model, log
x_t = sm.add_constant(x)
est = sm.GLM(y,x_t,family=sm.families.Gamma(link=sm.families.links.log))
est2 = est.fit()
print(est2.aic)
est2.summary()
# Out:
# 549.9998450110237
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     theoretical return   No. Observations:                  239
# Model:                            GLM   Df Residuals:                      231
# Model Family:                   Gamma   Df Model:                            7
# Link Function:                    log   Scale:                         0.26001
# Method:                          IRLS   Log-Likelihood:                -267.00
# Date:                Mon, 23 Mar 2020   Deviance:                       49.218
# Time:                        20:47:59   Pearson chi2:                     60.1
# No. Iterations:                    12
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               1.0116      0.196      5.174      0.000       0.628       1.395
# month              -0.0306      0.013     -2.293      0.022      -0.057      -0.004
# weekday            -0.0028      0.017     -0.170      0.865      -0.036       0.030
# hour               -0.0285      0.007     -3.859      0.000      -0.043      -0.014
# subscriber_0901 -8.545e-07    3.3e-06     -0.259      0.796   -7.33e-06    5.62e-06
# duration           -0.0001      0.000     -0.699      0.485      -0.001       0.000
# volume              0.8073      0.142      5.689      0.000       0.529       1.085
# ranked              0.0151      0.083      0.182      0.855      -0.147       0.178
# ===================================================================================
# """

# %% [markdown]
# ### model 3

# %%
#dependent and indepenedet variables in Binance
y = binance['theoretical return']
x = binance[['month','weekday', 'hour','subscriber_0901','duration', 'volume',
        'ranked']]

# %%
#ols model
import statsmodels.api as sm
from scipy import stats
x_t = sm.add_constant(x)
est = sm.OLS(y,x_t)
est2 = est.fit()
print(est2.aic)
est2.summary()
# Out:
# -413.157961321161
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     theoretical return   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     2.477
# Date:                Mon, 23 Mar 2020   Prob (F-statistic):             0.0178
# Time:                        20:47:59   Log-Likelihood:                 214.58
# No. Observations:                 261   AIC:                            -413.2
# Df Residuals:                     253   BIC:                            -384.6
# Df Model:                           7
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               1.0498      0.038     27.942      0.000       0.976       1.124
# month               0.0055      0.002      2.310      0.022       0.001       0.010
# weekday            -0.0058      0.003     -1.716      0.087      -0.012       0.001
# hour                0.0004      0.001      0.386      0.700      -0.002       0.003
# subscriber_0901 -4.296e-07   2.23e-07     -1.931      0.055   -8.68e-07    8.65e-09
# duration        -5.264e-05   2.17e-05     -2.425      0.016   -9.54e-05   -9.89e-06
# volume           1.918e-05    1.4e-05      1.371      0.172   -8.37e-06    4.67e-05
# ranked              0.0094      0.031      0.304      0.761      -0.051       0.070
# ==============================================================================
# Omnibus:                      227.641   Durbin-Watson:                   1.768
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3548.451
# Skew:                           3.574   Prob(JB):                         0.00
# Kurtosis:                      19.590   Cond. No.                     2.78e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.78e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#ols model + log 
import statsmodels.api as sm
from scipy import stats
x_t = sm.add_constant(x)
est = sm.GLM(y,x_t,family=sm.families.Gaussian(link=sm.families.links.log))
est2 = est.fit()
print(est2.aic)
est2.summary()
# Out:
# -413.3138271454816
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     theoretical return   No. Observations:                  261
# Model:                            GLM   Df Residuals:                      253
# Model Family:                Gaussian   Df Model:                            7
# Link Function:                    log   Scale:                        0.011654
# Method:                          IRLS   Log-Likelihood:                 214.66
# Date:                Mon, 23 Mar 2020   Deviance:                       2.9485
# Time:                        20:47:59   Pearson chi2:                     2.95
# No. Iterations:                     6
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0480      0.035      1.354      0.176      -0.022       0.118
# month               0.0052      0.002      2.332      0.020       0.001       0.010
# weekday            -0.0055      0.003     -1.740      0.082      -0.012       0.001
# hour                0.0004      0.001      0.376      0.707      -0.002       0.002
# subscriber_0901   -4.2e-07   2.15e-07     -1.956      0.050   -8.41e-07    7.77e-10
# duration        -5.165e-05   2.13e-05     -2.421      0.015   -9.35e-05   -9.83e-06
# volume           1.701e-05   1.23e-05      1.378      0.168   -7.18e-06    4.12e-05
# ranked              0.0103      0.029      0.353      0.724      -0.047       0.068
# ===================================================================================
# """

# %%
#gamma model, inverse
x_t = sm.add_constant(x)
est = sm.GLM(y,x_t,family=sm.families.Gamma())
est2 = est.fit()
print(est2.aic)
est2.summary()
# Out:
# -467.00424804863155
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     theoretical return   No. Observations:                  261
# Model:                            GLM   Df Residuals:                      253
# Model Family:                   Gamma   Df Model:                            7
# Link Function:          inverse_power   Scale:                       0.0099856
# Method:                          IRLS   Log-Likelihood:                 241.50
# Date:                Mon, 23 Mar 2020   Deviance:                       2.1058
# Time:                        20:47:59   Pearson chi2:                     2.53
# No. Iterations:                     6
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.9522      0.033     29.014      0.000       0.888       1.017
# month              -0.0048      0.002     -2.335      0.020      -0.009      -0.001
# weekday             0.0051      0.003      1.739      0.082      -0.001       0.011
# hour               -0.0004      0.001     -0.380      0.704      -0.002       0.002
# subscriber_0901  3.877e-07   1.99e-07      1.953      0.051   -1.38e-09    7.77e-07
# duration         4.848e-05   1.97e-05      2.459      0.014    9.83e-06    8.71e-05
# volume          -1.613e-05   1.14e-05     -1.418      0.156   -3.84e-05    6.17e-06
# ranked             -0.0085      0.027     -0.314      0.754      -0.062       0.045
# ===================================================================================
# """

# %%
#gamma model, log
import statsmodels.api as sm
from scipy import stats
x_t = sm.add_constant(x)
est = sm.GLM(y,x_t,family=sm.families.Gamma(link=sm.families.links.log))
est2 = est.fit()
print(est2.aic)
est2.summary()
# Out:
# -466.65421971685316
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     theoretical return   No. Observations:                  261
# Model:                            GLM   Df Residuals:                      253
# Model Family:                   Gamma   Df Model:                            7
# Link Function:                    log   Scale:                        0.010004
# Method:                          IRLS   Log-Likelihood:                 241.33
# Date:                Mon, 23 Mar 2020   Deviance:                       2.1084
# Time:                        20:47:59   Pearson chi2:                     2.53
# No. Iterations:                     9
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0494      0.035      1.421      0.155      -0.019       0.118
# month               0.0051      0.002      2.314      0.021       0.001       0.009
# weekday            -0.0053      0.003     -1.716      0.086      -0.011       0.001
# hour                0.0004      0.001      0.389      0.697      -0.002       0.002
# subscriber_0901 -3.972e-07   2.06e-07     -1.928      0.054   -8.01e-07    6.62e-09
# duration        -4.946e-05   2.01e-05     -2.461      0.014   -8.88e-05   -1.01e-05
# volume           1.831e-05    1.3e-05      1.413      0.158   -7.08e-06    4.37e-05
# ranked              0.0076      0.029      0.266      0.791      -0.048       0.064
# ===================================================================================
# """
